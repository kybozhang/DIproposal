# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
# Please see the submitted scripts on how this table was generated
m_r = {'Jan': [390, 1, 19, 120],
       'Feb': [883, 1, 34, 195],
       'Mae': [1162, 46, 37, 381],
       'Apr': [835, 157, 39, 400],
       'May': [437, 634, 7, 303],
       'Jun': [510, 3406, 4, 1198],
       'Jul': [670, 5786, 25, 2743],
       'Aug': [851, 5876, 16, 2680],
       'Sep': [314, 793, 23, 1032],
       'Oct': [438, 62, 35, 621],
       'Nov': [1159, 27, 25, 361],
       'Dec': [160, 1, 22, 140]}
data = pd.DataFrame(m_r).T
# Make the stacked area plot
plt.stackplot(data.index,  data[0],  data[1],  data[2], data[3], 
              labels=['Human','Lightning/Natural','Other', 'Unknown'])
plt.legend(loc='upper left')
plt.margins(0,0)
plt.ylabel('Wildfire Counts')
plt.title('Causes and stacked counts of wildfires by month')
plt.show()

print(data)
print("0 = Human, 1 = Lightning/Natural, 2 = Other, 3 = Unknown.")
# Out:
#         0     1   2     3
# Jan   390     1  19   120
# Feb   883     1  34   195
# Mae  1162    46  37   381
# Apr   835   157  39   400
# May   437   634   7   303
# Jun   510  3406   4  1198
# Jul   670  5786  25  2743
# Aug   851  5876  16  2680
# Sep   314   793  23  1032
# Oct   438    62  35   621
# Nov  1159    27  25   361
# Dec   160     1  22   140
# 0 = Human, 1 = Lightning/Natural, 2 = Other, 3 = Unknown.
