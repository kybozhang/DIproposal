# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from io import StringIO

#Please see the submitted scripts for the calculation of these averaged cost values
s = StringIO("""     COST/AREA   COST/TIME
A   189.9248921   13.42086449
B   1060.305805    60.7125806
C   411.8786625   8.306762703
D   560.0269129   16.44091537
E   351.0187276   4.190551252
F   1664.985624   14.69439201
G   3191.851954   5.033308682
H   397.5330841   9.173716812
I   133.5455243   6.572040811
J   135.6013389   1.942268906
K   196.9523182    17.4758504
L    301.746683   12.33447499
M   440.9336633   14.15999413""")

df = pd.read_csv(s, index_col=0, delimiter=' ', skipinitialspace=True)

fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df['COST/AREA'].plot(kind='bar', color='red', ax=ax, width=width, position=1)
df['COST/TIME'].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

plt.title('Area (Red) and time (blue) averaged cost of wildfires\n vs. different terrain/fuel types ')
ax.set_ylabel('COST/AREA (USD/ac)')
ax2.set_ylabel('COST/TIME (KUSD/hr)')
plt.show()
xaxis = ['Brush (2 feet)','Chaparral (6 feet)','Closed Timber Litter','Dormant Brush, Hardwood Slash',
         'Hardwood Litter','Light Logging Slash','Medium Logging Slash','Heavy Logging Slash','Short Grass (1 foot)',
         'Southern Rough','Tall Grass (2.5 feet)','Timber (Grass and Understory)','Timber (Litter and Understory)',]
for i in range(13):
    print("{} - {}".format(df.index[i], xaxis[i]))
# Out:
# A - Brush (2 feet)
# B - Chaparral (6 feet)
# C - Closed Timber Litter
# D - Dormant Brush, Hardwood Slash
# E - Hardwood Litter
# F - Light Logging Slash
# G - Medium Logging Slash
# H - Heavy Logging Slash
# I - Short Grass (1 foot)
# J - Southern Rough
# K - Tall Grass (2.5 feet)
# L - Timber (Grass and Understory)
# M - Timber (Litter and Understory)
